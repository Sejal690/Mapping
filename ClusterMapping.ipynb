# %% [markdown]
# <a href="https://colab.research.google.com/github/Sejal690/Mapping/blob/main/ClusterMapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install leafmap

# %%
import leafmap

# %%
map = leafmap.Map()
map
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %%
hq ="https://raw.githubusercontent.com/Sejal690/Mapping/refs/heads/main/Headquarters.csv"

# %%
map.add_points_from_xy(hq,x="X",y="Y")
map
# Out:
# Map(bottom=754.0, center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', …
